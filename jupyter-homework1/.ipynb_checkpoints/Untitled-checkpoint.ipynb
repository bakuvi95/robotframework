# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import csv

# %%
column_names = ["Date", "Price"]

# %%
df = pd.read_csv('daily_csv.csv', names = column_names)

# %%
Date = df.Date.to_list()

# %%
Price = df.Price.to_list()

# %%
plt.plot(Date, Price)
